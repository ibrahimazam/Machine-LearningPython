# %% [markdown]
# <span style="color:Yellow;">
#
# #### Neural Network Terminologies:
#
# <span style="color:Violet;">
#
# - Input X : its the data that added by the NN. not less than 2. some time will be more than thousands.
#
# $X_{1}$
#
# <span style="color:Yellow;">
#
# ### Activation Value (a):
#
# <span style="color:Violet;">
#
# - considered as output of any cell.
# - will replace X in some later layer.
#
# <img src = "images\replace.png" width="400" height="150">
#
# $a^{(2)}_{1} = $ Cell 1 layer 2
#
# $a^{(2)}_{2}= $ Cell 2 layer 2
#
# $a^{(2)}_{3}= $ Cell 3 layer 2
#
# <img src = "images\activation.png" width="200" height="200">
#
# ********************************************
# <span style="color:Yellow;">
#
# ### Theta:
#
# <span style="color:Violet;">
#
# - the required cofficient need to find it.
# - every cell has it own cofficient and required to find it.
#
# $\Theta ^{(1)}$
#
# ********************************************
#
# <span style="color:Yellow;">
#
# ### W:
#
# <span style="color:Violet;">
# - called weights.
# - its the matrix of thetas that required to find it in every layer.
# - Every Layer has its own W.
#
# $W ^{[1]}$
#
# ********************************************
#
# <span style="color:Yellow;">
#
# ### Z Value:
#
# <span style="color:Violet;">
#
# - Multiplying theta with X.
# - Every Cell has its Own Z.
# - all z value collected to every layer in big Z matrix.
#
# $Z^{(2)}$
#
# ********************************************
#
# <span style="color:Yellow;">
#
# ### The Value g:
#
# <span style="color:Violet;">
#
# - its the results of the input Z in sigmoid function.
# - all g values collected in matrix G to every layer.
#
# $g{(z^{(4)})}$
#
# ********************************************
#
# <span style="color:Yellow;">
#
# ### Layers:
#
# <span style="color:Violet;">
#
# - group of cells in same level.
# - The minumum level of layers is 3, and might include a hundred.
# - the middle layer is hidden.
#
# <img src = "images\Layers.png" width="300" height="180">"
#
#  ************************************
#
# <span style="color:Yellow;">
#
# ### Number of Layers L:
#
# <span style="color:Violet;">
#
# - refer to the total number of layers in cell.
# - the input and the outpu included in the total layers.
# - numbers of the unit in every Layer called Sl.
#
# $L = S_{l}$
#
# - Layer 3 = $S _{3}^{5}$
#
# <img src = "images\Layers.png" width="300" height="180">
#
#  ************************************
#
# <span style="color:Yellow;">
#
# ### The Actual value of y:
#
# <span style="color:Violet;">
#
# - the actual value of output.
# - will 0,1 in classification. and normal number or continues.
#
#  y
#
#  ************************************
#
# <span style="color:Yellow;">
#
# ### The predicted value
#
# <span style="color:Violet;">
#
# - its the output from NN.
# - symbolize as $\hat{y} $ or h(x) or a.
#
#
#  ************************************
#
# <span style="color:Yellow;">
#
# ### Delta:
#
# <span style="color:Violet;">
#
# - The differential between the predicted value and actual value.
# - it calculated by every components.
#
# $\delta{^{(L)}} = a^{(L)} - y ^{(t)}$

# %% [markdown]
#  ************************************
#
# <span style="color:Yellow;">
#
# ### Triangle Delta:
#
# <span style="color:Violet;">
#
# - its the sum of previous delta value.
# - its refer to total differential between predicted and actual
#
# $\Delta{^{(l)}_{i,j}}:$
#
#  ************************************
#
# <span style="color:Yellow;">
#
# ### Real Differential:
#
# <span style="color:Violet;">
#
# - The total differential (delta Triangle) after regularization.
# - sybolize as D
#
# $D ^{l}_{i,j}$
#
#  ************************************
#
# <span style="color:Yellow;">
#
# ### The total cost:
#
# <span style="color:Violet;">
#
# - Total cost, and should be calculated carefully.
# - Symbolize as J.
#
# $J{(\Theta)}$
#
#  ************************************
#
# <span style="color:Yellow;">
#
# ### Binary Classification:
#
# <span style="color:Violet;">
#
# - The NN will classify two cases.
# - Mostly might 0,1 true, false, yes or no.
#
# <img src = "images\bicl.png" width="400" height="150">
#
#  ************************************
#
# <span style="color:Yellow;">
#
# ### Multi Classification:
#
# <span style="color:Violet;">
#
# - The results more than two value.
# - Used for multichoice.
# - It has more than two output.
#
# <img src = "images\mucl.png" width="400" height="150">
#
#
#  ************************************
#
# <span style="color:Yellow;">
#
# ### Punctyation cell layer:
#
# <span style="color:Violet;">
#
# - the upper number refer to number of layer.
# - the lowes nu,ber refer to cell number
#
# $y^{(i)}_{k}$
#
# ************************************
#
# <span style="color:Yellow;">
#
# ### Cofficient of regularization:
#
# <span style="color:Violet;">
#
# - symbolize in lambda.
# - it choosed by some detereminants. and it changed for speed up the work.
#
# $\lambda$
