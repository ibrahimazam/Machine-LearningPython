# %% [markdown]
# <span style="color:Orange;">
#
# #### Math Equations for logical functions-2 Continue:
#
# <span style="color:Violet;">
#
# <span style="color:Turquoise;">
#
# - All the above functions has some formula logic, so that we can apply a code in program.
# - all formula should be clear to be able successfuly apply it in NN.
# - It happens by detrmine theta values which multiply with X.
# - all the value will apply by sigmoid function.
#
# ****************
#
# $\Theta _{0} = -30$
#
# $\Theta _{1} = 20$
#
# $\Theta _{2} = 20$
#
# $g(z) = \frac{1}{1 + e ^{-z}}$ .... $h _{\Theta} = g (-\Theta + \Theta x_{1} + \Theta x_{2})$
#
# $g(z) = \frac{1}{1 + e ^{-z}}$ .... $h _{\Theta} = g (-30 + 20x_{1} + 20x_{2})$
#
# $x_{1} = 0$
#
#
# $x_{2} = 1$
#
#
# Z = -30 + 0 + 20 * 1 = -10
#
# Z = -10
#
# <span style="color:Orange;">
#
# * $e^{-^{(-10)}} = \frac{1}{e^{10}} = \frac{1}{2.718^{10}} = \frac{1}{10000000} =$
#
# $g(z) = \frac{1}{1 + e ^{-10}}$ =   $\frac{1}{1+10000000}$ = 0
#
# when x1 = 0, X2 = 1 h(x)=0
# ********************************************************
# <span style="color:Turquoise;">
#
# $\Theta _{0} = -30$
#
# $\Theta _{1} =  20$
#
# $\Theta _{2} =  20$
#
# $g(z) = \frac{1}{1 + e ^{-z}}$ .... $h _{\Theta} = g (-\Theta + \Theta x_{1} + \Theta x_{2})$
#
# $g(z) = \frac{1}{1 + e ^{-z}}$ .... $h _{\Theta} = g (-30 + 20x_{1} + 20x_{2})$
#
# $x_{1} = 1$
#
# $x_{2} = 1$
#
# Z = -30 + 20 * 1 + 20 * 1 = 10
#
# Z = 10
#
# <span style="color:Orange;">
#
# $g(z) = \frac{1}{1 + e ^{-10}}$ = $\frac{1}{e^{10}}$ = $\frac{1}{2.718^{10}}$ = $\frac{1}{10000000}$ = almost Zero
#
# * $e^{-^{(10)}} = \frac{1}{e^{10}} = \frac{1}{2.718^{10}} = \frac{1}{10000000} = 0$  , $\frac{1}{1+0}=1$
#
# * when x1 and X2 = 1 h(x)=1
#
# **************************************
# <span style="color:Turquoise;">
#
# $\Theta _{0} = -30$
#
# $\Theta _{1} = 20$
#
# $\Theta _{2} = 20$
#
# $g(z) = \frac{1}{1 + e ^{-z}}$ .... $h _{\Theta} = g (-\Theta + \Theta x_{1} + \Theta x_{2})$
#
# $g(z) = \frac{1}{1 + e ^{-z}}$ .... $h _{\Theta} = g (-30 + 20x_{1} + 20x_{2})$
#
# $x_{1} = 0$
#
#
# $x_{2} = 0$
#
#
# Z = -30 + 0 + 0 = -30
#
# Z = -30
#
# <span style="color:Orange;">
#
# * $e^{-^{(-30)}} = \frac{1}{e^{30}} = \frac{1}{2.718^{30}} = \frac{1}{500000000} =$
#
# $g(z) = \frac{1}{1 + e ^{-30}}$ =   $\frac{1}{1+500000000}$ = 0
#
# when x1 = 0, X2 = 0 h(x)=0
# ********************************************************

# %% [markdown]
# <span style="color:Turquoise;">
#
# * AND Equation:
#
# $\begin{bmatrix}\color{red} X1 & \color{red} X2 &\color{red} a \\ 1 & 1 & 1 \\ 0 & 1 & 0 \\ 1 & 0 & 0 \\ 0 & 0 &0\end{bmatrix}$
#
# Formula (AND):
#
# $\Theta _{0} = -30 \ $,$ \Theta _{1} = 20 \ $,$\Theta _{2} = 20 \ $ Which is the Wight.
#
# $a = g(-30 + 20_{X1} + 20_{X2})$
#
# * The both of x1,x2 should be =1 for results =1
