# %% [markdown]
#  <span style="color:Violet;">
#
#  ************************************
#
# <span style="color:Yellow;">
#
# ### The Neural Network:
#
# <span style="color:Violet;">
#
# - While the cells combines in the brain, also combine with the code.
# - The inputs enter the cells below (3) the results output to every cell. (called new input) and thier output its the latest Output h(x).
# - Its not necessary that all the input share in all cells.
# - The input might increased or decreased.
# - The Layers level might increased.
#
# <img src = "images\NeuralCells.png" width="400" height="150">
#
#
#  ************************************
#
# <span style="color:Yellow;">
#
# ### Example:
#
# <span style="color:Violet;">
#
# - Regression issue.
# - Student admission to the university, depend on 3 skills, which is, mental ability, physical ability, socioeconomic.
# - We have (6) information each student: age, hight, whight, address, family income, latest degree.
# - What happened is the overlap between the inputs and the middle factors to achive suitable formula for evaluation.
# -  $X _{1} X _{2} X _{3} X _{4}X _{5} X _{6}$ - It could be classification but?
#
# * we will use the Nerual Network as:
# 1. Input as skills.
# 2. The information is the middle layer.
# 3. The output is h(x). (Admitted)
#
# <img src = "images\ExampleNeural.png" width="250" height="400">

# %% [markdown]
#  <span style="color:Violet;">
#
#  ************************************
#
# <span style="color:Yellow;">
#
# ### The Layer Of Neural Network:
#
# <span style="color:Violet;">
#
# - Some of the neural network will have more internal layer, which called hidden layer.
# - These Layer's accept the inputs from previous layer, and give the output as input to next layer.
# - The neural will have more that one hidden layer, when the hidden layer increased, thr perfromance increased as well. and got more complecated.
#
#
# <img src = "images\HiddenLayer.png" width="400" height="150">
#
# <span style="color:Yellow;">
#
# ### The Skill:
#
# <span style="color:Violet;">
#
# - That you need to define the right item or component.
# - The component will be used by one cell or more cells.
# - The number of cells and components will be in thousands.
#
# *********************************************
#
# <img src = "images\HiddenLayer1.png" width="400" height="150">
