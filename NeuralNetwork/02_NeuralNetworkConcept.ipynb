# %% [markdown]
# <span style="color:Yellow;">
#
# ### What is Neural Network:
#
# <span style="color:Violet;">
#
# - The idea come from our brain cells in how we think and handle data. in order to build similar algorithm.
# - the idea dosent have any reference to human brain. just in the way of how the sapines think.
# - very usefull when handling huge number of data.(100 X features).
#
# <img src="images\Neural.png" width="300" height="200">
#
# <span style="color:Yellow;">
#
# ### Neural Rewiring Experiment:
#
# <span style="color:Violet;">
#
# https://www.technologyreview.com/2008/10/15/33341/rewiring-the-brain/
# - The ear connect in his own nerves, access to Auditory Cortix (קליפת המוח השמיעתית)
# - The Scientists made an experiment with connect nerves from eye to the nerves of Auditory Cortix. they found some signals came from eye to Auditory Cortix.
# - The ape was able to use his eye while the nerves of his eye connected to Auditory Cortix.
# - same experiment with (sense of touch).
#
# * the sciense found that the brain able to learn and adapt and train from siganl what ever the source.
#
# <img src="images\Nerves.png" width="300" height="200">
#
# - Move a muscle: Paralyzed monkeys regained the ability to move their wrists when their nervous systems were rewired. By wiring brain cells directly to muscle cells via a computer that translates brain activity into an electrical jolt, researchers circumvented the faulty connection so that the monkeys could move their previously paralyzed wrists to manipulate a cursor into an onscreen box.
#
# <img src="images\ape.png" width="300" height="200">
#
#
# * From here the idea from Neural network came.
#
# <span style="color:yellow;">
#
# ### Brain Cell:
#
# <span style="color:Violet;">
# - brain cell called Neuron.
# - The purple part is the cell body, and the (dendrite) is the input.
# - The output is the yellow part (axon) which transfer the data and calculate math equation.
# - a lot of cells connecting with others, to think and make decision. they connected by electric signals.
#
# <img src="images\humannerual.png" width="400" height="200">
#
# <span style="color:yellow;">
#
# ### The Nerual netwotk:
#
# <span style="color:Violet;">
#
# - Designed in very similar way from brain cell.
# - The orange circle its the cell.
# - X vlaues which is the input (dedrite).
# - h(x) its the output.
# - The input provided, and the cell will calculate the value of h(x) which is the predicted value.
#
# - we just talking about code only, there is nothing called cells in computer just the idea...
#
# <img src="images\neuralcom.png" width="400" height="200">
#
# <span style="color:Yellow;">
#
# ### The calculation:
#
# <span style="color:Violet;">
#
# - h(x) Value calculated by sigmoid function. (in some cases)
# - the inputs which is X, Fetaures.
# - some time we add X0 with value 1, called unit of deviation (bias unit).
# - The (weights) used to refers thetas. which is the X coefficient.
#
# $ h _\theta (x) = \frac{1}{1 + e ^{-\theta ^{T}x}}$
