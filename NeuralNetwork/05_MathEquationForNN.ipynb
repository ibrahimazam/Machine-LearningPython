# %% [markdown]
# <span style="color:Yellow;">
#
# #### Math Equation for NN:
#
# <span style="color:Violet;">
#
# - The Steps of the Math Equation.
# - First Of all we have an numbers of X and er convert it to Z (Evrey Cell has its own Z) by multiplying the X with theta.
# - Next Step we convert Z to a (activation value)by Sigmoid function.
# - When we have a numbers of layers. a value will be handle as input.
# - X > Z, Z > a.
# - X * Theta With Sigmoid.
# - The bias its the cell of the cost.
#
# <span style="color:Yellow;">
#
# #### Math Equation for NN:
#
# <span style="color:Violet;">
#
# - In case the nerual 3 layers, which is input layer (does not include in the layers) and hidden layer and ouput layer. so we will have a nu,ber of math equation.
# - Every cell from second layer will has its own equation, and engage with other inputs.
# - Then will be an equation, that
#
# ************************************************************
#
# <span style="color:Yellow;">
#
# $a^{(2)}_{1} = g(\Theta ^{(1)}_{10}x_{0} + \Theta ^{(1)}_{11}x_{1} +\Theta ^{(1)}_{12}x_{2} + \Theta ^{(1)}_{13}x_{3})$
#
# $a^{(2)}_{2} = g(\Theta ^{(1)}_{20}x_{0} + \Theta ^{(1)}_{21}x_{1} +\Theta ^{(1)}_{22}x_{2} + \Theta ^{(1)}_{23}x_{3})$
#
# $a^{(2)}_{3} = g(\Theta ^{(1)}_{30}x_{0} + \Theta ^{(1)}_{31}x_{1} +\Theta ^{(1)}_{32}x_{2} + \Theta ^{(1)}_{33}x_{3})$
#
# $h _\Theta(x) = a^{(3)}_{1} = g (\Theta ^{(2)}_{10}a^{(2)}_{0} + \Theta ^{(2)}_{11}a^{(2)}_{1}  +\Theta ^{(2)}_{12}a^{(2)}_{2}  + \Theta ^{(2)}_{13}a^{(2)}_{3} ) $
#
#
#  ----------------------
# $\Theta ^{(1)}_{10}x_{0}$ = From Cell 0 (bias) To Cell 1 the 10 its 1 and 0. the 1 above 1-0 its layer 1. * x 0
#
# $\Theta ^{(1)}_{11}x_{1} $ = From Cell 1 to cell 1
#
#
# $a^{(2)}_{2}$ = Which is $Z^{2}_{2}$ $\Theta ^{(1)}_{20}x_{0} $ = From Cell 1 to cell 1
#
# - Layer 2 $a^{(2)}_{2}$ 4 cells as input which is, x0, and then 21 which is from cell 1 to 2.
#
# <span style="color:Turquoise;">
#
# *****************************************
# ### The Theta Matrix
#
# $\Theta^{(1)}_{10} \ \Theta^{(1)}_{11} \ \Theta^{(1)}_{12} \ \Theta^{(1)}_{13}$
#
# $\Theta^{(1)}_{20}  \ \Theta^{(1)}_{21} \ \Theta^{(1)}_{22} \ \Theta^{(1)}_{23}$
#
# $\Theta^{(1)}_{30} \ \Theta^{(1)}_{31} \ \Theta^{(1)}_{32}\  \Theta^{(1)}_{33}$
#
#
#  *********************************************************
#
# <img src = "images\MathEq.png" width="900" height="150">
