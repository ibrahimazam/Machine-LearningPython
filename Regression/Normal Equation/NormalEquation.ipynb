# %% [markdown]
# <span style="color:MediumOrchid;">
#
# - derivatives
# - Tangent line קו משיק
# - Every Curve פרוגריסיבי prgeressive the value of differential will be postive

# %%
from IPython.display import Image
Image ('images\Tanget.png')

# %%
from IPython.display import Image
Image ('images\Tanget1.png')

# %% [markdown]
# <span style="color:MediumOrchid;">
#
# - The poin tof Maximum Values and Minmum Values its appear when the derivatives equal to 0

# %%
from IPython.display import Image
Image ('images\Tangetgarphs.png')

# %% [markdown]
# <span style="color:MediumOrchid;">
#
# - Normal Equation:
#
# - is an analytical approach to Linear Regression with a Least Square Cost Function. We can directly find out the value of θ without using Gradient Descent. Following this approach is an effective and time-saving option when are working with a dataset with small features
#
# $ \theta = (X ^{T}X) ^{-1} . (X^{T}y)$
