# %% [markdown]
# y = mx + c
#
# Theta 0 y intercept
#
# Theta 1 = Slope
#
# $ \color{Yellow}  \theta _{0} \theta _{1} Decide _{} for  the  best  fit  line $

# %%
import numpy as np 
import matplotlib.pyplot as plt
x=  np.array([100,200,300,400,500,600,700,800,900])
y = np.array([10,12,14,16,18,20,22,24,26])

plt.style.use('dark_background')
plt.scatter(x,y, color = 'red')
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()
