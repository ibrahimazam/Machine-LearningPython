# %%
#quadratic function
#פונקציה ריבועית 
from IPython.display import Image
Image(filename='images\quadratic function.png')

# %%
#quadratic function
#פונקציה מעוקבת 
from IPython.display import Image
Image(filename='images\cubicfunction.png')

# %%
#quadratic function
#פונקציית שורש ריבועית 
from IPython.display import Image
Image(filename='images\Squarerootfunction.png')
