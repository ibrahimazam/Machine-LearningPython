# %% [markdown]
# <span style="color:Yellow;">
# https://en.wikipedia.org/wiki/Logarithm
#
# Muhammad ibn Musa al-Khwarizmi
#
# Logarithms came from Khwarizmi its starts from Khwarizm - and then the Eu changed it to algorithms.
#
# What is Logarithms:
#
# Its number of zeros in front of the numbers
#
# Family of 10
#
# Log 10 = 1
#
# Log 100 = 2
#
# Log 1000 = 3
#
# Log 100000 = 5
#
# Log Billion = 9
#
# What about 50?
#
# Log 50 =1.69 Why? its between 1 and 2 and not linear colleration.
#
# Log 7000 =3.84
#
# Log 3 million = 6.4
#
# <span style="color:red;">
# Basis of algorithm:
#
# - In origin the basis should be 10 but some time there is some different number to the basis
#
# $Log _{4} 30$
#
# $Log _{12} 165$
#
# $Log _{14} 6378$
#
# $Log _{>1} ^{>=1}$
#
#
#
# <span style="color:MediumOrchid;">
#
# - Algorithm principle:
#
# - Exponentiation
#
# $Log _{C} A = B  =====>>>  C ^{B} = A$
#
# $Log _{7} 49 = 2  =====>>> 7 ^{2} = 49$
#
# 7 X 7 = 49
#
# $L _{5}X = 4$ = 625
#
#
# $L _{X}64 = $ = 6
#
# The Normal number e:
#
# - equal 2.718
#
# - come from math corrleation
#
# - with in condition the X should be huge number
#
# $e = (1+1 /x)^{x}$
#
# - Very Useful in integration.
#
# $e = (1.00000000001)^{1000000000000} = 2.718$
#
# - Natuarl number ln:
# - normal algorthim but the base is normal number 2.718
# - Lograthim natural number
#
# $ln 200 = 5.29 =====>> e^{5.29}= 200$
#
# $ln = e = 1 =====>> e^{1} = e$
#
#
# ### Negative exponent:
# ## מכנה ומונה
#
# - if the the number is normal we put it in positive denominator
#
# $5 ^{-2} = 1/5 ^{2} = 125 = 0.04$
#
# - When the number is denominator
#
# $1/5^{-3} = 5^{3} = 125$
#
# - when the number is fraction
#
# $(3/5)^{4} = (5/3)^{4} = 625/81$
#
#
# $קו השבר\frac{מונה}{מכנה}$
