# %% [markdown]
# <span style="color:Yellow;">
#
# ### Regularization Techniques:
#
# <span style="color:Violet;">
#
# - Definition:
# - the process of pure the data to get rid of overfiting.
# - it happen by three important method and we apply one or two or three together.
# 1. L1 regularization
# 2. L2 regularization
# 3. Dropout regularization
#
# <span style="color:Yellow;">
#
# * Data Selection:
#
# <span style="color:Violet;">
#
# - It means select the features that used by the algorithm.
# - Exists features not affect the required results it will drive to mislead to algorithm.
# - in this step you need to get advice with professional. which that depend in special data.
# - Example:
# - what will affect the quality of potato (heightوweightوcolorوsoil typeوamount of waterوcompostوtemperatureوwindوthe sun...)
# - remove the features that dosent have weight it lead to imporve the algorithm.
# - while choose the rows (m) has a huge impact in the quality of the data.
# - example:
# - data should be mixed not only has one type (just Men, or just women , or just sick, or from one country...etc)
#
# <span style="color:Yellow;">
#
# * Change the coefficient:
#
# <span style="color:Violet;">
#
# - it means by change the coefficient of features that affect the output but not a huge change.
#
# $ 5X + 4y = 5 = coefficient $
#
# - Example:
# - The temperature of the city in which the student lives, will affect little bit on his score.
# - lest see below equation that has 4 coefficients affect the X 1,2,3,4:
#
# $\theta _{0} \ \theta _{1}{x} \ \theta _{2}{x}_{2} \ \theta _{3}{x}_{3} \ \theta _{4}{x}_{4}$
#
# $ X 1 , X 2 (has huge impact), X 3 , X 4 (also has some impact)$
#
# - We will change the coefficient which is theta.
#
# <span style="color:Yellow;">
#
# - Change the coefficient:
#
# - it happens by add big numbers to the coefficient to reduce the cost function.
#
# $min _{0} \frac{1}{2m} \sum\limits _{i=1} ^{m} (\theta (x^{(i)})-y^{(i)})^{2} + 1000.\theta^{2}_{3} + 1000.\theta^{2}_{4}$
#
# <span style="color:Violet;">
#
# - when we add big numbers side the required thetas to reduce it. it will force the equation to reduce the value.
#
# <span style="color:Yellow;">
#
# * add lambda $ \lambda $:
#
# <span style="color:Violet;">
#
# - usually called coefficient (Regularzation factor)
# - we multiplicate in thr sum of square all the thetas (except theta 0) and the we add the cost function.
#
# <span style="color:Yellow;">
#
# $min _{0} \frac{1}{2m} \sum\limits _{i=1} ^{m} (\theta (x^{(i)})-y^{(i)})^{2} + \lambda \sum\limits _{i=1} ^{n} \theta ^{2}_{j} $
#
# $\theta _{1}{x}^{2} \ \theta _{2}{x}^{2} \ \theta _{3}{x}^{3} \ \theta _{4}{x}^{4}$
#
# <span style="color:Violet;">
#
# - when choose some value of lambda, then add the eqution to algorithm we will see the Overfiting start to disapear.
# - If the Overfiting still appear we will change the value of Lmabda until we solve the OF.
#
#
# - The tunined equation
#
# Repeat {
#
# $\color{red} \theta _{0}$ $\color{yellow}   := \theta _{0} - \alpha \frac{1}{m} \sum\limits _{i=1} ^{m} (h _\theta (x ^{(i)}) -y ^{(i)}) x _{\theta}^{(i)}$
#
# $\color{red} \theta _{0}$ $\color{yellow}   := \theta _{0} - \alpha [( \frac{1}{m} \sum\limits _{i=1} ^{m} (h _\theta (x ^{(i)}) -y ^{(i)}) x _{\theta}^{(i)}) + \frac{\lambda}{m}{\theta}_{j}]$  $ \ j \in {1,2...n}$
# }
