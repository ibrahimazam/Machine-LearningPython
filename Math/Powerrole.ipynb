# %% [markdown]
# 1. כפל חזקות
#
# $a^{m} * a ^{n} = a^{m+n}$
#
# $3^{4} * 3 ^{2} = 3^{m+n} = 3^{6}$
#
# בסיס החזקה חייב להיות אותו בסיס
#
# 2. חילוק החזקות
#
# $\frac{a^{m}}{a^{n}}=a^{m-n}$
#
# $\frac{6^{10}}{6^{2}}=6^{10-2}= 6^{8}$
#
# 3. חזקה של חזקה
#
# $(a^{m})^{n} = a^{m*n}$
#
# $(4^{2})^{3} = 4^{2*3} = 4^{6}$
#
# 4. פתיחת סוגריים
#
# $(a*b*c)^{m}= a^{m} * b^{m}* c^{m}$
#
# $(2*3*4)^{10}= 2^{10} * 3^{10}* 4^{10}$
#
# 5. חזקה עם משתנה
#
# $4 ^{x} + ^{2x} = 4^{3x}$
#
# $(6^{2a})^{5}= 6^{2a*5} = 6^{10a}$
#
# $5x^{4} * 3x^{3}= x^{4+3} * 15 = 15x^{7}$
#
# $\frac{6x^{7}}{2x^{2}}= $
#
# $\frac{6x}{2x}=3x$
#
# $3x^{7-2} = 3x^{5}$
#
# 6. חוקים שונים
#
# $\frac{x^{4} * x^{5}}{x^{6}}=$
#
# $\frac{x^{9}}{x^{6}}=$
#
# $x^{9-6} = x^{3}$
#
# $\frac{8x^{2}*x^{6}}{-2x^{7}*2x^{3}}$
#
# $\frac{8x^{8}{-4x{10}}}=$
#
# $-2x^{8-10} = -2x^{-2}$
#
# 7. חוקי חזקות 1,0
#
# $7 = 7^{1}$
#
# $x= x^{1}$
#
# $6 * 6 ^{8} = 6^{1} * 6^{8} = 6^{9}$
#
# $6^{0} = 1$
#
# $x^{0} = 1$
#
# כל מספר בחזקת 0 שווה לאחד
#
# $1^{3} = 1* 1* 1 = 1$
#
# $1^{100}=1$
#
# $0^{2} = 0* 0* = 0$
#
# $0^{100}=0$
#
# 0 power 0 its not defined
#
#
# 8. חוק של חזקות שלישלות
#
# $a^{-n} = \frac{1}{a^{n}}$
#
# $5^{-2} = \frac{1}{5^{2}}$
#
# $\frac{1}{a^{-n}}= a^{n}$
#
# $\frac{1}{11^{-4}}= 11^{4}$
#
# 9. חוק חזקה על שבר
#
# $\frac{(a)}{(b)}^{n} = \frac{(3)}{(7)}^{n} = \frac{3^{n}}{7^{n}}$
#
# 10. חיבור חזקות
#
# אין לחבר חזקות אם אין אותה חזקה
#
# אין לחבר אם בסיסי החזקה שונים
#
# $3x^{7}+2x^{7}= 5x^{7}$
#
# $6x^{5}-4x^{5}= 2x^{5}$
#
# $6x^{5}-4x^{5}= x^{5} (6-4)$
#
# $x^{5}*2 = 2x^{5}$
